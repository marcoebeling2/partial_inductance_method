# %% [markdown]
# ### Partial Inductance Method

# %%
import pim_methods as pim 
import macros_classes as macro

# %% [markdown]
# Change path to coil info

# %%
coil_info = './example/coil_info.txt'
M_matrix, resistances, Q_factors, coils = pim.run_computations(coil_info, export=True, jupiter = True)

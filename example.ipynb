# %%
from functions import *

# %% [markdown]
# ### Select folder and calculate inductance matrix

# %%
path = "./" # path to file (leave as "./" if file is in the same directory as this script)
filename = "example.txt" # change this to the file of the txt
generate_ind_matrix(path + filename, True)
# Out:
# Mutual Inductance Matrix
#
# File: test_coil.txt
#
#
# Format:
#  [L11, M12, M13, ...]
#  [M21, L22, M23, ...]
#  [M31, M32, L33, ...]
#  ...
#
#
# Inductance Matrix:
#
# [[7.714760e-07, 1.218557e-07],
#  [1.218557e-07, 7.714760e-07]]
#
#
# Alternate Method for Self Inductance for Circular Cross Sections
#
# [[6.259769e-07, 1.218557e-07],
#  [1.218557e-07, 6.259769e-07]]
#
#
# Time taken: 1.58 seconds
